# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
sns.set_style('whitegrid')
sns.color_palette('pastel')
# %matplotlib inline
from sklearn.metrics import roc_curve
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.grid_search import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.cross_validation import KFold, cross_val_score, train_test_split
import xgboost as xgb
#Settings
pd.options.mode.chained_assignment = None
pd.set_option('display.max_columns', 1000)

# %%
train_data = pd.read_csv('~/PYTHON/DrivenData/water_pumps/train_data.csv')
test_data = pd.read_csv('~/PYTHON/DrivenData/water_pumps/test_data.csv')
train_target = pd.read_csv('~/PYTHON/DrivenData/water_pumps/train_target.csv')

# %%
print(test_data.shape)
print(train_data.shape)
print(train_target.shape)
# Out:
# (14850, 40)
# (59400, 40)
# (59400, 2)

# %%
#Functions

def binary(x):
    if (x == True) or (x == 'True'):
        return 1
    elif (x == False) or (x == 'False'):
        return 0


def funder_cat(x):
    
    if x <= 1:
        return 's1'
    elif (x>1) & (x<=5):
        return 's2'
    elif (x>5) & (x<=10):
        return 's3'
    elif (x>10) & (x<=20):
        return 's4'
    elif (x>20) & (x<=50):
        return 's5'
    elif (x>50) & (x<=100):
        return 's6'
    elif (x>100) & (x<=150):
        return 's7'
    elif (x>150) & (x<=200):
        return 's8'
    elif (x>200):
        return 's9'

def installer_cat(x):
    
    if x <= 1:
        return 'i1'
    elif (x>1) & (x<=5):
        return 'i2'
    elif (x>5) & (x<=10):
        return 'i3'
    elif (x>10) & (x<=20):
        return 'i4'
    elif (x>20) & (x<=50):
        return 'i5'
    elif (x>50) & (x<=100):
        return 'i6'
    elif (x>100) & (x<=150):
        return 'i7'
    elif (x>150) & (x<=200):
        return 'i8'
    elif (x>200):
        return 'i9'


def funder_clean(data):

    funder_piv = data.pivot_table(index='funder', values='id', aggfunc=len)
    funder_df = pd.DataFrame()
    funder_df['type'] = funder_piv.index
    funder_df['count'] = funder_piv.values
    funder_df['funder_size'] = funder_df['count'].apply(lambda x: funder_cat(x))
    funder_map = dict(funder_df[['type', 'funder_size']].values)
    data['funder_size'] = data.funder.map(funder_map)
    data.funder_size.fillna('None', inplace=True)
    data = data.drop(['funder'], axis=1)
    return data


def installer_clean(data):

    installer_piv = data.pivot_table(index='installer', values=['id'], aggfunc=len)
    installer_df = pd.DataFrame()
    installer_df['type'] = installer_piv.index
    installer_df['count'] = installer_piv.values
    installer_df['installer_size'] = installer_df['count'].apply(lambda x: installer_cat(x))
    installer_map = dict(installer_df[['type', 'installer_size']].values)
    data['installer_size'] = data.installer.map(installer_map)
    data.installer_size.fillna('None', inplace=True)
    data = data.drop(['installer'], axis=1)
    return data


def date_recorded_year(x):
    return datetime.datetime.strptime(x, '%Y-%m-%d').year

# %%
# Major Clean Function
def rf_prepare_data(data_input):
    
    data = data_input
    ## Handling Null Values
    # scheme name dropped
    data.drop(['scheme_name'],axis=1, inplace=True)
    
    # public_meeting NaN filled to False and cleaned
    data.public_meeting.fillna(False, inplace=True)
    data['public_meeting_binary'] = data.public_meeting.apply(binary)
    data.drop(['public_meeting'],axis=1,inplace=True)
    
    # scheme_management NaN filled to 'None' string
    data.scheme_management.fillna('None', inplace=True)
    
    # funder cleaning
    data = funder_clean(data)
    
    # installer cleaning
    data = installer_clean(data)
    
    # permit cleaning
    data.permit[(data.permit!=False)&(data.permit!=True)] = False
    data['permit_binary'] = data.permit.apply(binary)
    data.drop(['permit'],axis=1,inplace=True)
    
    # subvillage drop
    data.drop(['subvillage'],axis=1, inplace=True)
    
    ##Handling other data
    # date_recorded_year extract
    data['date_recorded_year'] = data.date_recorded.apply(lambda x: date_recorded_year(x))
    data.drop(['date_recorded'],axis=1,inplace=True)
    
    # wpt_name drop
    data.drop(['wpt_name'], axis=1, inplace=True)
    # region drop
    data.drop(['region'], axis=1, inplace=True)
    # lga drop
    data.drop(['lga'], axis=1, inplace=True)
    # ward drop
    data.drop(['ward'], axis=1, inplace=True)
    # recorded_by drop
    data.drop(['recorded_by'], axis=1, inplace=True)
    # extraction_type_drop
    data.drop(['extraction_type','extraction_type_group'], axis=1, inplace=True)
    # management drop
    data.drop(['management'], axis=1, inplace=True)
    # payment drop
    data.drop(['payment'], axis=1, inplace=True)
    # water_quality drop
    data.drop(['water_quality'], axis=1, inplace=True)
    # quantity drop
    data.drop(['quantity'], axis=1, inplace=True)
    # source drop
    data.drop(['source','source_class'],axis=1,inplace=True)
    # waterpoint_type drop
    data.drop(['waterpoint_type'], axis=1, inplace=True)
    # num_private drop
    #data.drop(['num_private'], axis=1,inplace=True)
    # drop coordinates
    #data.drop(['longitude','latitude'], axis=1,inplace=True)
    
    # Operational Years Feature Engineering
    op_years = list(data.date_recorded_year-data.construction_year)
    operational_years = []
    for i in op_years:
        if (i > 500) or (i < 0):
            operational_years.append(0)
        else:
            operational_years.append(i)
    data['operational_years'] = operational_years
#     data.drop(['date_recorded_year','construction_year'], axis=1, inplace=True)
 
    return data

# %%
def transform_data(data):
    
    # Transformation of variables if required or for testing
    data['amount_tsh'] = data.amount_tsh.apply(lambda x: np.log(x+1))
    data['operational_years'] = data.operational_years.apply(lambda x: np.log(x+1))
    data['population'] = data.population.apply(lambda x: np.log(x+1))
    
    return data

# %%
rf_data = pd.read_csv('~/PYTHON/DrivenData/water_pumps/train_data.csv')

# %%
prep_rf = rf_prepare_data(rf_data)
rf_targets = train_target.status_group

# %%
# col = pandas.Categorical.from_array(income["workclass"])
# income["workclass"] = col.codes
# print(income["workclass"].head(5))

iter_ = ['basin','scheme_management','extraction_type_class','management_group',
        'payment_type','quality_group','quantity_group','source_type','waterpoint_type_group',
        'funder_size','installer_size']

for idx in iter_:
    col_ = pd.Categorical.from_array(prep_rf[idx])
    prep_rf[idx]= col_.codes

prep_rf
# Out:
#           id  amount_tsh  gps_height  longitude      latitude  num_private  \
# 0      69572      6000.0        1390  34.938093 -9.856322e+00            0
# 1       8776         0.0        1399  34.698766 -2.147466e+00            0
# 2      34310        25.0         686  37.460664 -3.821329e+00            0
# 3      67743         0.0         263  38.486161 -1.115530e+01            0
# 4      19728         0.0           0  31.130847 -1.825359e+00            0
# 5       9944        20.0           0  39.172796 -4.765587e+00            0
# 6      19816         0.0           0  33.362410 -3.766365e+00            0
# 59397  37057         0.0           0  34.017087 -8.750434e+00            0
# 59398  31282         0.0           0  35.861315 -6.378573e+00            0
# 59399  26348         0.0         191  38.104048 -6.747464e+00            0
#
#        basin  region_code  district_code  population  scheme_management  \
# 0          1           11              5         109                  7
# 1          4           20              2         280                  2
# 2          5           21              4         250                  7
# 3          7           90             63          58                  7
# 4          4           18              1           0                  1
# 5          5            4              8           1                  7
# 6          0           17              3           0                  7
# 7          3           17              3           0                  1
# 8          3           14              6           0                  7
# 9          4           18              1           0                  1
# 10         8           60             43         345                  4
# 11         1           10              5         250                  9
# 12         0           17              2           0                  9
# 13         5            3              7           1                 10
# 14         0           17              6           0                  9
# 15         3           15              2         200                  7
# 16         6           11              4          35                  8
# 17         6           11              4          50                  8
# 18         4           19              1        1000                  1
# 19         1           11              5           1                  7
# 20         1           11              4           4                  7
# 21         4           17              1           0                  9
# 22         6           11              4         350                  8
# 23         5            3              3         210                 11
# 24         3           16              3         156                  7
# 25         5            3              4         140                  7
# 26         7           80             23         260                  7
# 27         4           18              1           0                  1
# 28         5            3              1           1                  0
# 29         5            3              7           1                 10
# ...      ...          ...            ...         ...                ...
# 59370      3           16              2           1                  1
# 59371      4           17              2           0                  9
# 59372      3           14              4           0                  4
# 59373      2           15              1          96                  7
# 59374      4           17              1           0                  9
# 59375      5            4              4         609                  7
# 59376      0           13              2           1                  7
# 59377      0           14              2           0                 11
# 59378      6           11              4          36                  7
# 59379      4           18              3           0                  7
# 59380      1           11              5          50                  7
# 59381      5            4              8         360                  7
# 59382      5            3              4           1                 10
# 59383      7           80             62         800                  1
# 59384      4           18             30           0                  7
# 59385      4           20              4         200                  9
# 59386      2           15              2        1000                  7
# 59387      8            7              2         100                  8
# 59388      3           16              1         500                  7
# 59389      3           15              3        1500                  7
# 59390      3           15              2         150                  7
# 59391      5            3              3         210                 11
# 59392      2           12              1           0                  7
# 59393      0           14              2           0                 11
# 59394      8            5              6          89                  7
# 59395      5            3              5         125                 10
# 59396      6           11              4          56                  7
# 59397      6           12              7           0                  7
# 59398      6            1              4           0                  7
# 59399      8            5              2         150                  7
#
#        construction_year  extraction_type_class  management_group  \
# 0                   1999                      0                 4
# 1                   2010                      0                 4
# 2                   2009                      0                 4
# 3                   1986                      5                 4
# 4                      0                      0                 1
# 5                   2009                      5                 4
# 6                      0                      1                 4
# 7                      0                      1                 4
# 8                      0                      1                 4
# 9                      0                      1                 4
# 10                  2011                      5                 0
# 11                  1987                      1                 4
# 12                     0                      1                 4
# 13                  2009                      0                 4
# 14                     0                      1                 4
# 15                  1991                      1                 4
# 16                  1978                      0                 4
# 17                  1978                      0                 4
# 18                  1999                      3                 4
# 19                  1992                      0                 4
# 20                  2008                      0                 4
# 21                     0                      1                 4
# 22                  1978                      0                 4
# 23                  2011                      0                 4
# 24                  2009                      0                 4
# 25                  1974                      0                 4
# 26                  2011                      1                 4
# 27                     0                      1                 4
# 28                  2000                      0                 0
# 29                  2002                      0                 4
# ...                  ...                    ...               ...
# 59370                  0                      3                 3
# 59371                  0                      1                 4
# 59372                  0                      3                 0
# 59373               1988                      1                 4
# 59374                  0                      1                 4
# 59375               2005                      0                 4
# 59376               1990                      3                 4
# 59377                  0                      0                 4
# 59378               2008                      0                 4
# 59379                  0                      0                 4
# 59380               1999                      0                 4
# 59381               1992                      0                 4
# 59382               2008                      0                 4
# 59383               2008                      1                 4
# 59384                  0                      0                 4
# 59385               2011                      1                 4
# 59386               2009                      1                 4
# 59387               2000                      5                 4
# 59388               1995                      0                 4
# 59389               2009                      1                 4
# 59390               1991                      1                 4
# 59391               1967                      0                 4
# 59392                  0                      0                 4
# 59393                  0                      0                 0
# 59394               2007                      5                 4
# 59395               1999                      0                 4
# 59396               1996                      0                 4
# 59397                  0                      1                 4
# 59398                  0                      1                 4
# 59399               2002                      1                 4
#
#        payment_type  quality_group  quantity_group  source_type  \
# 0                 0              2               1            6
# 1                 2              2               2            3
# 2                 5              2               1            1
# 3                 2              2               0            0
# 4                 2              2               3            3
# 5                 5              4               1            2
# 6                 2              2               1            0
# 7                 6              3               1            5
# 8                 2              4               3            0
# 9                 2              2               1            5
# 10                2              4               1            0
# 11                3              2               2            5
# 12                4              2               1            5
# 13                1              2               1            6
# 14                2              2               1            5
# 15                2              2               1            0
# 16                1              2               0            4
# 17                3              2               0            4
# 18                2              3               2            6
# 19                0              2               1            6
# 20                1              2               1            6
# 21                6              5               4            5
# 22                2              2               1            4
# 23                1              2               1            4
# 24                6              2               1            6
# 25                6              2               1            6
# 26                1              2               1            0
# 27                2              2               1            5
# 28                1              2               2            6
# 29                1              2               1            6
# ...             ...            ...             ...          ...
# 59370             1              5               4            2
# 59371             2              2               1            5
# 59372             5              4               2            5
# 59373             0              2               1            0
# 59374             4              2               1            5
# 59375             1              2               1            4
# 59376             6              5               0            5
# 59377             2              2               2            1
# 59378             1              2               1            6
# 59379             2              2               1            6
# 59380             0              2               0            6
# 59381             2              2               2            6
# 59382             5              2               1            6
# 59383             6              2               1            3
# 59384             2              2               2            6
# 59385             1              4               1            0
# 59386             2              2               1            0
# 59387             5              2               1            0
# 59388             6              2               2            6
# 59389             2              2               1            0
# 59390             2              2               2            0
# 59391             2              2               1            4
# 59392             2              2               1            6
# 59393             5              2               2            1
# 59394             1              2               1            0
# 59395             5              2               1            6
# 59396             0              2               1            4
# 59397             1              1               1            0
# 59398             2              2               2            5
# 59399             3              4               1            5
#
#        waterpoint_type_group  public_meeting_binary  funder_size  \
# 0                          1                      1            9
# 1                          1                      0            6
# 2                          1                      1            3
# 3                          1                      1            9
# 4                          1                      1            1
# 5                          1                      1            7
# 6                          3                      1            9
# 7                          3                      1            9
# 8                          3                      1            9
# 9                          3                      1            4
# 10                         5                      1            9
# 11                         3                      1            9
# 12                         3                      1            9
# 13                         1                      1            8
# 14                         3                      1            5
# 15                         3                      1            9
# 16                         1                      1            9
# 17                         1                      1            9
# 18                         5                      0            9
# 19                         1                      1            9
# 20                         1                      1            6
# 21                         3                      0            9
# 22                         1                      1            9
# 23                         1                      1            9
# 0      6000.0        1390  34.938093  -9.856322            0      1
# 1         0.0        1399  34.698766  -2.147466            0      4
# 2        25.0         686  37.460664  -3.821329            0      5
# 3         0.0         263  38.486161 -11.155298            0      7
# 4         0.0           0  31.130847  -1.825359            0      4
#
#    region_code  district_code  population  scheme_management  \
# 0           11              5         109                  7
# 1           20              2         280                  2
# 2           21              4         250                  7
# 3           90             63          58                  7
# 4           18              1           0                  1
#
#    construction_year  extraction_type_class  management_group  payment_type  \
# 0               1999                      0                 4             0
# 1               2010                      0                 4             2
# 2               2009                      0                 4             5
# 3               1986                      5                 4             2
# 4                  0                      0                 1             2
#
#    quality_group  quantity_group  source_type  waterpoint_type_group  \
# 0              2               1            6                      1
# 1              2               2            3                      1
# 2              2               1            1                      1
# 3              2               0            0                      1
# 4              2               3            3                      1
#
#    public_meeting_binary  funder_size  installer_size  permit_binary  \
# 0                      1            9               6              0
# 1                      0            6               5              1
# 2                      1            3               9              1
# 3                      1            9               9              1
# 4                      1            1               7              1
#
#    date_recorded_year  operational_years
# 0                2011                 12
# 1                2013                  3
# 2                2013                  4
# 3                2013                 27
# 4                2011                  0

# %%
rf_model = RandomForestClassifier(random_state = 123, n_estimators = 100)
rf_model.fit(prep_rf, rf_targets)
predictions = rf_model.predict(prep_rf)
print(len(rf_targets[rf_targets==predictions])/len(rf_targets))
# Out:
# 0.9957070707070707

# %%
kf = KFold(prep_rf.shape[0], n_folds=10,shuffle=True,random_state=123)
cvs = cross_val_score(rf_model,prep_rf, rf_targets,cv=kf)

# %%
print(np.mean(cvs))
cvs
# Out:
# 0.804797979798
# array([ 0.80808081,  0.80959596,  0.79983165,  0.80084175,  0.80622896,
#         0.80488215,  0.81649832,  0.796633  ,  0.80117845,  0.80420875])

# %%
test_prep_rf = rf_prepare_data(test_data)
iter_ = ['basin','scheme_management','extraction_type_class','management_group',
        'payment_type','quality_group','quantity_group','source_type','waterpoint_type_group',
        'funder_size','installer_size']

for idx in iter_:
    col_ = pd.Categorical.from_array(test_prep_rf[idx])
    test_prep_rf[idx]= col_.codes
test_prep_rf.drop(['id'],axis=1,inplace=True)
test_prep_rf.head()
# Out:
#    amount_tsh  gps_height  longitude   latitude  num_private  basin  \
# 0         0.0        1996  35.290799  -4.059696            0      0
# 1         0.0        1569  36.656709  -3.309214            0      5
# 2         0.0        1567  34.767863  -5.004344            0      0
# 3         0.0         267  38.058046  -9.418672            0      7
# 4       500.0        1260  35.006123 -10.950412            0      7
#
#    region_code  district_code  population  scheme_management  \
# 0           21              3         321                  3
# 1            2              2         300                  7
# 2           13              2         500                  7
# 3           80             43         250                  7
# 4           10              3          60                 10
#
#    construction_year  extraction_type_class  management_group  payment_type  \
# 0               2012                      3                 2             2
# 1               2000                      0                 4             2
# 2               2010                      3                 4             2
# 3               1987                      3                 4             6
# 4               2000                      0                 4             1
#
#    quality_group  quantity_group  source_type  waterpoint_type_group  \
# 0              2               3            3                      5
# 1              2               2            6                      1
# 2              2               2            3                      5
# 3              2               0            5                      5
# 4              2               1            6                      1
#
#    public_meeting_binary  funder_size  installer_size  permit_binary  \
# 0                      1            6               5              1
# 1                      1            9               9              1
# 2                      1            0               0              0
# 3                      0            3               3              1
# 4                      0            3               3              1
#
#    date_recorded_year  operational_years
# 0                2013                  1
# 1                2013                 13
# 2                2013                  3
# 3                2013                 26
# 4                2013                 13

# %%
col_
# Out:
# [i5, i9, None, i3, i3, ..., i6, i2, None, i9, i9]
# Length: 14850
# Categories (10, object): [None, i1, i2, i3, ..., i6, i7, i8, i9]

# %%
def iterate_rf(iterations,X_train,Y_train,X_final):
    kf = KFold(X_train.shape[0], n_folds=10,shuffle=True,random_state=123)
    
    pred_df = pd.DataFrame()
    accuracies = []
    
    for i in range(iterations):
        rf_model = RandomForestClassifier(n_estimators = 100)
        xtrain, xtest, ytrain, ytest = train_test_split(X_train, Y_train, test_size=0.33, random_state=123)
        
        rf_model.fit(xtrain,ytrain)
        predictions = rf_model.predict(xtest)
        acc = len(ytest[ytest==predictions])/len(ytest)
        accuracies.append(acc)
        final_predictions = rf_model.predict(X_final)
        pred_df[i] = final_predictions
    return pred_df, accuracies

# rf_df, rf_accuracies = iterate_rf(100,prep_rf, rf_targets,test_prep_rf)

# %%
rf_df, rf_accuracies = iterate_rf(200,prep_rf, rf_targets,test_prep_rf)

# %%
t_prep_rf = transform_data(prep_rf)
t_test_prep_rf = transform_data(test_prep_rf)

# %%
t_rf_df, t_rf_accuracies = iterate_rf(200,t_prep_rf, rf_targets, t_test_prep_rf)

# %%
print(rf_accuracies)
print(t_rf_accuracies)
# Out:
# [0.8006325885113764, 0.7992041628405264, 0.7992041628405264, 0.800734618916437, 0.800581573308846, 0.7985409652076318, 0.7999183756759515, 0.7982348739924497, 0.8001224364860728, 0.7990001020304051, 0.7996122844607693, 0.8001224364860728, 0.8006325885113764, 0.8010407101316193, 0.7983369043975105, 0.8004285277012549, 0.8012447709417406, 0.7996122844607693, 0.8009386797265585, 0.8001224364860728, 0.7985409652076318, 0.7984389348025712, 0.799561269258239, 0.8010407101316193, 0.7993061932455872, 0.7992041628405264, 0.7993061932455872, 0.8003775124987246, 0.7976226915620855, 0.800734618916437, 0.7994082236506479, 0.800275482093664, 0.799561269258239, 0.7995102540557086, 0.7992551780430568, 0.8008876645240282, 0.8003264972961943, 0.7995102540557086, 0.7990511172329354, 0.7996632996632996, 0.8001734516886032, 0.7985409652076318, 0.7993061932455872, 0.8001734516886032, 0.8000204060810121, 0.7990511172329354, 0.7975206611570248, 0.79971431486583, 0.8011427405366799, 0.8006325885113764, 0.7995102540557086, 0.8004285277012549, 0.7996122844607693, 0.7982858891949801, 0.8008876645240282, 0.7994082236506479, 0.7982858891949801, 0.8005305581063157, 0.79971431486583, 0.7999183756759515, 0.8004795429037853, 0.7995102540557086, 0.7998673604734211, 0.7987450260177533, 0.79971431486583, 0.8001224364860728, 0.798847056422814, 0.7996632996632996, 0.7996122844607693, 0.8004795429037853, 0.7996632996632996, 0.7995102540557086, 0.7987960412202837, 0.8006836037139068, 0.7996122844607693
# %%
submission2 = pd.DataFrame()
submission2['id']=test_data['id']
submission2['status_group'] = rf_df.iloc[:,0]
submission2.to_csv('~/PYTHON/DrivenData/water_pumps/submission_2.csv',index=False)

# %%
submission3 = pd.DataFrame()
submission3['id']=test_data['id']
submission3['status_group'] = t_rf_df.iloc[:,0]
submission3.to_csv('~/PYTHON/DrivenData/water_pumps/submission_3.csv',index=False)

# %%
best_idx = rf_accuracies.index(max(rf_accuracies))
submission4 = pd.DataFrame()
submission4['id']=test_data['id']
submission4['status_group'] = t_rf_df.iloc[:,best_idx]
submission4.to_csv('~/PYTHON/DrivenData/water_pumps/submission_4.csv',index=False)

# %%
t_best_idx = t_rf_accuracies.index(max(t_rf_accuracies))
submission5 = pd.DataFrame()
submission5['id']=test_data['id']
submission5['status_group'] = t_rf_df.iloc[:,t_best_idx]
submission5.to_csv('~/PYTHON/DrivenData/water_pumps/submission_5.csv',index=False)

# %%
print(max(rf_accuracies))
print(max(t_rf_accuracies))
# Out:
# 0.8018569533721049
# 0.8021120293847567

# %%
print(rf_df.shape)
rf_df.head()
# Out:
# (14850, 200)
#               0               1               2               3    \
# 0  non functional  non functional  non functional  non functional
# 1      functional      functional      functional      functional
# 2      functional      functional      functional      functional
# 3  non functional  non functional  non functional  non functional
# 4      functional      functional      functional      functional
#
#               4               5               6               7    \
# 0  non functional  non functional  non functional  non functional
# 1      functional      functional      functional      functional
# 2      functional      functional      functional      functional
# 3  non functional  non functional  non functional  non functional
# 4      functional      functional      functional      functional
#
#               8               9               10              11   \
# 0  non functional  non functional  non functional  non functional
# 1      functional      functional      functional      functional
# 2      functional      functional      functional      functional
# 3  non functional  non functional  non functional  non functional
# 4      functional      functional      functional      functional
#
#               12              13              14              15   \
# 0  non functional  non functional  non functional  non functional
# 1      functional      functional      functional      functional
# 2      functional      functional      functional      functional
# 3  non functional  non functional  non functional  non functional
# 4      functional      functional      functional      functional
#
#               16              17              18              19   \
# 0  non functional  non functional  non functional  non functional
# 1      functional      functional      functional      functional
# 2      functional      functional      functional      functional
# 3  non functional  non functional  non functional  non functional
# 4      functional      functional      functional      functional
#
#               20              21              22              23   \
# 0  non functional  non functional  non functional  non functional
# 1      functional      functional      functional      functional
# 2      functional      functional      functional      functional
# 3  non functional  non functional  non functional  non functional
# 4      functional      functional      functional      functional
#
#               24              25              26              27   \
# 0  non functional  non functional  non functional  non functional
# 1      functional      functional      functional      functional
# 2      functional      functional      functional      functional
# 3  non functional  non functional  non functional  non functional
# 4      functional      functional      functional      functional
#
#               28              29              30              31   \
# 0  non functional  non functional  non functional  non functional
# 1      functional      functional      functional      functional
# 2      functional      functional      functional      functional
# 3  non functional  non functional  non functional  non functional
# 4      functional      functional      functional      functional
#
#               32              33              34              35   \
# 0  non functional  non functional  non functional  non functional
# 1      functional      functional      functional      functional
# 2      functional      functional      functional      functional
# 3  non functional  non functional  non functional  non functional
# 4      functional      functional      functional      functional
#
#               36              37              38              39   \
# 0  non functional  non functional  non functional  non functional
# 1      functional      functional      functional      functional
# 2      functional      functional      functional      functional
# 3  non functional  non functional  non functional  non functional
# 4      functional      functional      functional      functional
#
#               40              41              42              43   \
# 0  non functional  non functional  non functional  non functional
# 1      functional      functional      functional      functional
# 2      functional      functional      functional      functional
# 3  non functional  non functional  non functional  non functional
# 4      functional      functional      functional      functional
#
#               44              45              46              47   \
# 0  non functional  non functional  non functional  non functional
# 1      functional      functional      functional      functional
# 2      functional      functional      functional      functional
# 3  non functional  non functional  non functional  non functional
# 4      functional      functional      functional      functional
#
#               48              49              50              51   \
# 0  non functional  non functional  non functional  non functional
# 1      functional      functional      functional      functional
# 2      functional      functional      functional      functional
# 3  non functional  non functional  non functional  non functional
# 4      functional      functional      functional      functional
#
#               52              53              54              55   \
# 0  non functional  non functional  non functional  non functional
# 1      functional      functional      functional      functional
# 2      functional      functional      functional      functional
# 3  non functional  non functional  non functional  non functional
# 4      functional      functional      functional      functional
#
#               56              57              58              59   \
# 0  non functional  non functional  non functional  non functional
# 1      functional      functional      functional      functional
# 2      functional      functional      functional      functional
# 3  non functional  non functional  non functional  non functional
# 4      functional      functional      functional      functional
#
#               60              61              62              63   \
# 0  non functional  non functional  non functional  non functional
# 1      functional      functional      functional      functional
# 2      functional      functional      functional      functional
# 3  non functional  non functional  non functional  non functional
# 4      functional      functional      functional      functional
#
#               64              65              66              67   \
# 0  non functional  non functional  non functional  non functional
# 1      functional      functional      functional      functional
# 2      functional      functional      functional      functional
# 3  non functional  non functional  non functional  non functional
# 4      functional      functional      functional      functional
#
#               68              69              70              71   \
# 0  non functional  non functional  non functional  non functional
# 1      functional      functional      functional      functional
# 2      functional      functional      functional      functional
# 3  non functional  non functional  non functional  non functional
# 4      functional      functional      functional      functional
#
#               72              73              74              75   \
# 0  non functional  non functional  non functional  non functional
# 1      functional      functional      functional      functional
# 2      functional      functional      functional      functional
# 3  non functional  non functional  non functional  non functional
# 4      functional      functional      functional      functional
#
#               76              77              78              79   \
# 0  non functional  non functional  non functional  non functional
# 1      functional      functional      functional      functional
# 2      functional      functional      functional      functional
# 3  non functional  non functional  non functional  non functional
# 4      functional      functional      functional      functional
#
#               80              81              82              83   \
# 0  non functional  non functional  non functional  non functional
# 1      functional      functional      functional      functional
# 2      functional      functional      functional      functional
# 3  non functional  non functional  non functional  non functional
# 4      functional      functional      functional      functional
#
#               84              85              86              87   \
# 0  non functional  non functional  non functional  non functional
# 1      functional      functional      functional      functional
# 2      functional      functional      functional      functional
# 3  non functional  non functional  non functional  non functional
# 4      functional      functional      functional      functional
#
#               88              89              90              91   \
# 0  non functional  non functional  non functional  non functional
# 1      functional      functional      functional      functional
# 2      functional      functional      functional      functional
# 3  non functional  non functional  non functional  non functional
# 4      functional      functional      functional      functional
#
#               92              93              94              95   \
# 0  non functional  non functional  non functional  non functional
# 1      functional      functional      functional      functional
# 2      functional      functional      functional      functional
# 3  non functional  non functional  non functional  non functional
# 4      functional      functional      functional      functional
#
#               96              97              98              99   \
# 0  non functional  non functional  non functional  non functional
# 1      functional      functional      functional      functional
# 2      functional      functional      functional      functional
# 3  non functional  non functional  non functional  non functional
# 4      functional      functional      functional      functional
#
#               100             101             102             103  \
# 0  non functional  non functional  non functional  non functional
# 1      functional      functional      functional      functional
# 2      functional      functional      functional      functional
# 3  non functional  non functional  non functional  non functional
# 4      functional      functional      functional      functional
#
#               104             105             106             107  \
# 0  non functional  non functional  non functional  non functional
# 1      functional      functional      functional      functional
# 2      functional      functional      functional      functional
# 3  non functional  non functional  non functional  non functional
# 4      functional      functional      functional      functional
#
#               108             109             110             111  \
# 0  non functional  non functional  non functional  non functional
# 1      functional      functional      functional      functional
# 2      functional      functional      functional      functional
# 3  non functional  non functional  non functional  non functional
# 4      functional      functional      functional      functional
#
#               112             113             114             115  \
# 0  non functional  non functional  non functional  non functional
# 1      functional      functional      functional      functional
# 2      functional      functional      functional      functional
# 3  non functional  non functional  non functional  non functional
# 4      functional      functional      functional      functional
#
#               116             117             118             119  \
# 0  non functional  non functional  non functional  non functional
# 1      functional      functional      functional      functional
# 2      functional      functional      functional      functional
# 3  non functional  non functional  non functional  non functional
# 4      functional      functional      functional      functional
#
#               120             121             122             123  \
# 0  non functional  non functional  non functional  non functional
# 1      functional      functional      functional      functional
# 2      functional      functional      functional      functional
# 3  non functional  non functional  non functional  non functional
# 4      functional      functional      functional      functional
#
#               124             125             126             127  \
# 0  non functional  non functional  non functional  non functional
# 1      functional      functional      functional      functional
# 2      functional      functional      functional      functional
# 3  non functional  non functional  non functional  non functional
# 4      functional      functional      functional      functional
#
#               128             129             130             131  \
# 0  non functional  non functional  non functional  non functional
# 1      functional      functional      functional      functional
# 2      functional      functional      functional      functional
# 3  non functional  non functional  non functional  non functional
# 4      functional      functional      functional      functional
#
#               132             133             134             135  \
# 0  non functional  non functional  non functional  non functional
# 1      functional      functional      functional      functional
# 2      functional      functional      functional      functional
# 3  non functional  non functional  non functional  non functional
# 4      functional      functional      functional      functional
#
#               136             137             138             139  \
# 0  non functional  non functional  non functional  non functional
# 1      functional      functional      functional      functional
# 2      functional      functional      functional      functional
# 3  non functional  non functional  non functional  non functional
# 4      functional      functional      functional      functional
#
#               140             141             142             143  \
# 0  non functional  non functional  non functional  non functional
# 1      functional      functional      functional      functional
# 2      functional      functional      functional      functional
# 3  non functional  non functional  non functional  non functional
# 4      functional      functional      functional      functional
#
#               144             145             146             147  \
# 0  non functional  non functional  non functional  non functional
# 1      functional      functional      functional      functional
# 2      functional      functional      functional      functional
# 3  non functional  non functional  non functional  non functional
# 4      functional      functional      functional      functional
#
#               148             149             150             151  \
# 0  non functional  non functional  non functional  non functional
# 1      functional      functional      functional      functional
# 2      functional      functional      functional      functional
# 3  non functional  non functional  non functional  non functional
# 4      functional      functional      functional      functional
#
#               152             153             154             155  \
# 0  non functional  non functional  non functional  non functional
# 1      functional      functional      functional      functional
# 2      functional      functional      functional      functional
# 3  non functional  non functional  non functional  non functional
# 4      functional      functional      functional      functional
#
#               156             157             158             159  \
# 0  non functional  non functional  non functional  non functional
# 1      functional      functional      functional      functional
# 2      functional      functional      functional      functional
# 3  non functional  non functional  non functional  non functional
# 4      functional      functional      functional      functional
#
#               160             161             162             163  \
# 0  non functional  non functional  non functional  non functional
# 1      functional      functional      functional      functional
# 2      functional      functional      functional      functional
# 3  non functional  non functional  non functional  non functional
# 4      functional      functional      functional      functional
#
#               164             165             166             167  \
# 0  non functional  non functional  non functional  non functional
# 1      functional      functional      functional      functional
# 2      functional      functional      functional      functional
# 3  non functional  non functional  non functional  non functional
# 4      functional      functional      functional      functional
#
#               168             169             170             171  \
# 0  non functional  non functional  non functional  non functional
# 1      functional      functional      functional      functional
# 2      functional      functional      functional      functional
# 3  non functional  non functional  non functional  non functional
# 4      functional      functional      functional      functional
#
#               172             173             174             175  \
# 0  non functional  non functional  non functional  non functional
# 1      functional      functional      functional      functional
# 2      functional      functional      functional      functional
# 3  non functional  non functional  non functional  non functional
# 4      functional      functional      functional      functional
#
#               176             177             178             179  \
# 0  non functional  non functional  non functional  non functional
# 1      functional      functional      functional      functional
# 2      functional      functional      functional      functional
# 3  non functional  non functional  non functional  non functional
# 4      functional      functional      functional      functional
#
#               180             181             182             183  \
# 0  non functional  non functional  non functional  non functional
# 1      functional      functional      functional      functional
# 2      functional      functional      functional      functional
# 3  non functional  non functional  non functional  non functional
# 4      functional      functional      functional      functional
#
#               184             185             186             187  \
# 0  non functional  non functional  non functional  non functional
# 1      functional      functional      functional      functional
# 2      functional      functional      functional      functional
# 3  non functional  non functional  non functional  non functional
# 4      functional      functional      functional      functional
#
#               188             189             190             191  \
# 0  non functional  non functional  non functional  non functional
# 1      functional      functional      functional      functional
# 2      functional      functional      functional      functional
# 3  non functional  non functional  non functional  non functional
# 4      functional      functional      functional      functional
#
#               192             193             194             195  \
# 0  non functional  non functional  non functional  non functional
# 1      functional      functional      functional      functional
# 2      functional      functional      functional      functional
# 3  non functional  non functional  non functional  non functional
# 4      functional      functional      functional      functional
#
#               196             197             198             199
# 0  non functional  non functional  non functional  non functional
# 1      functional      functional      functional      functional
# 2      functional      functional      functional      functional
# 3  non functional  non functional  non functional  non functional
# 4      functional      functional      functional      functional

# %%
submission = pd.DataFrame()
submission['id']=test_data['id']
submission['status_group'] = rf_df.iloc[:,0]

# %%
# submission.set_index(submission['id'],inplace=True)
# submission
submission.head()
# Out:
#       id    status_group
# 0  50785  non functional
# 1  51630      functional
# 2  17168      functional
# 3  45559  non functional
# 4  49871      functional

# %%
submission.to_csv('~/PYTHON/DrivenData/water_pumps/submission_1.csv',index=False)
